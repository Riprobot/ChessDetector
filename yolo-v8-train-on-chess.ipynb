yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230702%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230702T112841Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !wget -O 'normal_dataset.zip' 'https://app.roboflow.com/ds/F1EHmMccFM?key=LUYXR3jOP2'
# !unzip -q 'normal_dataset.zip' -d 'datasets/normal_dataset'
# Out:
# --2023-07-02 11:28:51--  https://app.roboflow.com/ds/F1EHmMccFM?key=LUYXR3jOP2
# Resolving app.roboflow.com (app.roboflow.com)... 151.101.65.195, 151.101.1.195
# Connecting to app.roboflow.com (app.roboflow.com)|151.101.65.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/HNdaXd2DnYZUt9enVxm0kETE5s82/spS4pVpmmZcTKko5mXFX/1/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230702%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230702T112851Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !wget -O 'final_dataset.zip' 'https://app.roboflow.com/ds/3mheRfV23g?key=a7kvIWxtIh'
# !unzip -q 'final_dataset.zip' -d 'datasets/final_dataset'
# Out:
# --2023-07-02 11:28:56--  https://app.roboflow.com/ds/3mheRfV23g?key=a7kvIWxtIh
# Resolving app.roboflow.com (app.roboflow.com)... 151.101.65.195, 151.101.1.195
# Connecting to app.roboflow.com (app.roboflow.com)|151.101.65.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/HNdaXd2DnYZUt9enVxm0kETE5s82/4OIjpglt3eefhKLwyJtQ/8/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230702%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230702T112856Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# %%capture

# !pip install ultralytics
# !pip install shapely

# %%
from ultralytics import YOLO

from matplotlib.pyplot import figure
import matplotlib.image as image
from matplotlib import pyplot as plt


import pandas as pd
import numpy as np
from numpy import asarray
from PIL import Image

import cv2

# %%
model_trained = YOLO('/kaggle/working/best_transformed_detection.pt')

# %%
model_trained.train(data = '/kaggle/working/datasets/warm_up_dataset/data.yaml',epochs=60, imgsz=416)
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.10 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
model_trained.train(data = '/kaggle/working/datasets/normal_dataset/data.yaml',epochs=100, imgsz=416)
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.10 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
results = model_trained.predict(source='/kaggle/working/datasets/normal_dataset/test/images/d7887071e972604ddf5940d8eb2702e7_jpg.rf.a39c6243f21c1dc718143d46b328f772.jpg', line_thickness=1, conf=0.2, augment=False, save_txt=True, save=True)
# Out:
# WARNING ⚠️ 'line_thickness' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'line_width' instead.
#
# image 1/1 /kaggle/working/datasets/normal_dataset/test/images/d7887071e972604ddf5940d8eb2702e7_jpg.rf.a39c6243f21c1dc718143d46b328f772.jpg: 416x416 1 black-bishop, 1 black-king, 1 black-knight, 3 black-pawns, 1 black-rook, 1 white-bishop, 1 white-king, 1 white-knight, 3 white-pawns, 1 white-queen, 1 white-rook, 32.9ms
# Speed: 6.1ms preprocess, 32.9ms inference, 14.3ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict3
# 1 label saved to runs/detect/predict3/labels

# %%
model_trained.train(data = '/kaggle/working/datasets/final_dataset/data.yaml',epochs=100, imgsz=416)
# Out:
# Ultralytics YOLOv8.0.124 🚀 Python-3.10.10 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
model_trained.to('cpu')

# %%
print(model_trained)

# %%
results = model_trained.predict(source='/content/test/images/410993714e325a1de3e394ffe860df3a_jpg.rf.657c49ca295ef54da23469189070a075.jpg', line_thickness=1, conf=0.2, augment=False, save_txt=True, save=True)
# Out:
# WARNING ⚠️ 'line_thickness' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'line_width' instead.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 results = model_trained.predict(source='/content/test/images/410993714e325a1de3e394ffe860df3a_jpg.rf.657c49ca295ef54da23469189070a075.jpg', line_thickness=1, conf=0.2, augment=False, save_txt=True, save=True)
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py:255, in YOLO.predict(self, source, stream, **kwargs)
# ...
